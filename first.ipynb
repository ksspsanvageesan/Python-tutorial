# %%
a=10

# %%
file=open("notes.txt","w")
file.write("Hello World")
file.close()
file=open("notes.txt","r")
content = file.read()
print(content)
# Out:
# Hello World

# %%
file=open("notes.txt","r")
content = file.read()
print(content)
# Out:
# Hello World

# %%
file=open("notes.txt","r")
print(file.read())
file.close()
# Out:
# Hello World

# %%
file=open("notes.txt","a")
file.write("added newly")
file.close()

# %%
file=open("notes.txt","a")
file.write("\n added newly again \n")
file.write("added newly 3rd time\n 4th line")
file.close()

# %%
with open("notes.txt","r") as file:
    content = file.read()
    print(content)
# Out:
# Hello Worldadded newly
#  added newly again
# added newly 3rd time
#  added newly again
# added newly 3rd time
#  4th line

# %%
import os

os.getcwd()
# Out:
# 'd:\\Python tutorial'

# %%
os.listdir()
# Out:
# ['.vscode',
#  'calculator.py',
#  'file.txt',
#  'first.ipynb',
#  'notes.txt',
#  'psvageesan',
#  'test.py']
